# %% [markdown]
# # Costa Rica Institute of Technology
# * Course: MP-6122 Pattern Recognition
# * Student: Jose Martinez Hdez
# * Course: Data Science
# * Year: 2022
# * Laboratory 1: Introduction to Pattern Recognition

# %%
print("Holaaa")
for i in range(10):
  if(i%2 != 0):
    print(i)
  else:
    print("Nouuuu")
# Out:
# Holaaa
# Nouuuu
# 1
# Nouuuu
# 3
# Nouuuu
# 5
# Nouuuu
# 7
# Nouuuu
# 9

# %% [markdown]
# • Buscar un dataset de su preferencia, recomendaci n que pueda explotar la
# parte de EDA y pre-procesado.
# • Aplicar todas las t cnicas posibles de EDA.
# • Aplicar todas las t cnicas de pre-procesado posibles.
# • NOTA: Validar si a nivel de investigaci n de tesis, hay alguna componente
# que haga sentido en esta tem tica (hacer propuesta antes del 30 de
# febrero). Basado en el resultado, la estar amos incorporando a esta
# investigaci n.

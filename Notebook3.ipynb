# %% [markdown]
# # Costa Rica Institute of Technology
# * Course: MP-6122 Pattern Recognition
# * Student: Jose Martinez Hdez
# * Year: 2022
# * Notebook 3: CNN and ANN

# %% [markdown]
# # Activation Functions
#
# In neural networks, the activation functions are the functions that are applied to the output of the neurons. The mathematical definition of a neuron is described as follows, with the input $x$ and the output $y$:
#
# \begin{equation}
# \begin{aligned}
# \mathbf{y} &= f(\mathbf{w}^T \mathbf{x} + \mathbf{b}) \\
# \end{aligned}
# \end{equation}
#
# Where $f$ is known as the activation function. This equation is described in the following image:
#
# ![ensemble](images/activation.png)
#
# An activation function decides whether a neuron should be activated or not. This means that it will decide whether the neuron’s input to the network is important or not in the process of prediction using simpler mathematical operations.
#
# **References**:
#
# - https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html
# - https://cs231n.github.io/neural-networks-1/
# - https://www.v7labs.com/blog/neural-networks-activation-functions

# %% [markdown]
# ## Unit Step Function
#
# A unit step activation function is a much-used feature in neural networks. The output assumes value 0 for negative argument and 1 for positive argument. The range is between $(0,1)$ and the output is binary in nature. These types of activation functions are useful for binary schemes. When we want to classify an input model in one of two groups, we can use a binary compiler with a unit step activation function. A unit step activation function is described with the following equation:
#
# \begin{equation}
# f(x) =
# \begin{cases}
#     1 & \text{if } x \ge 0 \\
#     0 & \text{if } x < 0 \\
# \end{cases}
# \end{equation}
#
# Some limitations of this activation function are that it is not differentiable and it is not differentiable at $x = 0$, which causes problems in the backpropagation algorithm. And it cannot provide multi-value outputs—for example, it cannot be used for multi-class classification problems.
#
# **References**:
#
# - https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html
# - https://cs231n.github.io/neural-networks-1/
# - https://www.oreilly.com/library/view/neural-networks-with/9781788397872/c5736f7e-91cb-4811-bed8-d746140d3eec.xhtml#:~:text=A%20unit%20step%20activation%20function,output%20is%20binary%20in%20nature.

# %%
import numpy as np
from matplotlib import pyplot as plt 

def unit_step(x):
    y = np.zeros_like(x)

    y[x>=0] = 1

    return y

x = np.arange(-5, 5, 0.1)

plt.figure(figsize=(10,10))
plt.title("Unit Step Function")
plt.xlabel("X") 
plt.ylabel("Y") 
plt.plot(x, unit_step(x),'r') 
plt.grid()
plt.show()

# %% [markdown]
# ## Sign (Signum) Function
#
# This activation function is used to classify a binary input model in two groups. The output is between $(-1,1)$ and the output is continuous in nature. The sign function is defined as:
#
# \begin{equation}
# f(x) =
# \begin{cases}
#     1 & \text{if } x > 0 \\
#     0 & \text{if } x = 0 \\
#     -1 & \text{if } x < 0 \\
# \end{cases}
# \end{equation}
#
# It`s similar to the unit step function, but it can provide multi-value outputs—for example, it can be used for multi-class classification problems.
#
# **References**:
#
# - https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html
# - https://cs231n.github.io/neural-networks-1/
# - https://www.v7labs.com/blog/neural-networks-activation-functions

# %%
import numpy as np
from matplotlib import pyplot as plt 

def signum(x):
    y = np.zeros_like(x)

    y[x>=0] = 1
    y[x<0] = -1

    return y

x = np.arange(-5, 5, 0.1)

plt.figure(figsize=(10,10))
plt.title("Signum Function")
plt.xlabel("X") 
plt.ylabel("Y") 
plt.plot(x, signum(x),'r') 
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Function
#
# The linear activation function is also known as Identity Function where the activation is proportional to the input. The output is the same as the input. The range is between $(-\infty, \infty)$ and the output is continuous in nature. These types of activation functions are useful for continuous schemes. When we want to classify an input model in one of two groups, we can use a continuous compiler with a linear activation function. A linear activation function is described with the following equation:
#
# \begin{equation}
# f(x) = x
# \end{equation}
#
# Some pros of this activation function are:
#
# - It gives a range of activations, so it is not binary activation.
# - We can definitely connect a few neurons together and if more than 1 fires, we could take the max ( or softmax) and decide based on that.
#
# And some limitations of this activation function are:
#
# - For this function, derivative is a constant. That means, the gradient has no relationship with $x$.
# - It is a constant gradient and the descent is going to be on constant gradient.
# - If there is an error in prediction, the changes made by back propagation is constant and not depending on the change in input.
#
# **References**:
#
# - https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html
# - https://cs231n.github.io/neural-networks-1/
# - https://www.v7labs.com/blog/neural-networks-activation-functions

# %%
import numpy as np
from matplotlib import pyplot as plt 

def linear(x):
    return x

x = np.arange(-5, 5, 0.1)

plt.figure(figsize=(10,10))
plt.title("Linear Function")
plt.xlabel("X") 
plt.ylabel("Y") 
plt.plot(x, linear(x),'r') 
plt.grid()
plt.show()

# %% [markdown]
# ## Piecewise Linear Function
#
# A piecewise linear function is a function defined on a (possibly unbounded) interval of real numbers, such that there is a collection of intervals on each of which the function is an affine function. If the domain of the function is compact, there needs to be a finite collection of such intervals; if the domain is not compact, it may either be required to be finite or to be locally finite in the reals. The piecewise linear function is defined by the following equation:
#
# \begin{equation}
# f(x) =
# \begin{cases}
#     0 & \text{if } x < 0 \\
#     x & \text{if } x \ge 0 \\
# \end{cases}
# \end{equation}
#
# **References**:
#
# - https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html
# - https://cs231n.github.io/neural-networks-1/
# - https://www.v7labs.com/blog/neural-networks-activation-functions

# %%
import numpy as np
from matplotlib import pyplot as plt 

def piecewise_linear(x):
    y = np.zeros_like(x)

    y[x>=0] = x[x>=0]
    y[x<0] = 0

    return y

x = np.arange(-5, 5, 0.1)

plt.figure(figsize=(10,10))
plt.title("Piecewsise Linear Function")
plt.xlabel("X") 
plt.ylabel("Y") 
plt.plot(x, piecewise_linear(x),'r') 
plt.grid()
plt.show()

# %% [markdown]
# ## Logistic (Sigmoid) Function
#
# This function takes any real value as input and outputs values in the range of $0$ to $1$.  The larger the input (more positive), the closer the output value will be to $1.0$, whereas the smaller the input (more negative), the closer the output will be to $0.0$, as shown below. Mathematically it can be represented as:
#
# \begin{equation}
# f(x) = \frac{1}{1 + e^{-x}}
# \end{equation}
#
# Here’s why sigmoid/logistic activation function is one of the most widely used functions:
#
# - It is commonly used for models where we have to predict the probability as an output. Since probability of anything exists only between the range of 0 and 1, sigmoid is the right choice because of its range.
# - The function is differentiable and provides a smooth gradient, i.e., preventing jumps in output values. This is represented by an S-shape of the sigmoid activation function.
#
#
# **References**:
#
# - https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html
# - https://cs231n.github.io/neural-networks-1/
# - https://www.v7labs.com/blog/neural-networks-activation-functions

# %%
import numpy as np
from matplotlib import pyplot as plt 

def sigmoid(x):
    return 1/(1+np.exp(-x))
    
x = np.arange(-5, 5, 0.1)

plt.figure(figsize=(10,10))
plt.title("Sigmoid Function")
plt.xlabel("X") 
plt.ylabel("Y") 
plt.plot(x, sigmoid(x),'r') 
plt.grid()
plt.show()

# %% [markdown]
# ## Hyperbolic Tangent Function
#
# The hyperbolic tangent function is an old mathematical function. It was first used in the work by L'Abbe Sauri (1774). Tanh function is very similar to the sigmoid/logistic activation function, and even has the same S-shape with the difference in output range of $-1$ to $1$. In Tanh, the larger the input (more positive), the closer the output value will be to $1.0$, whereas the smaller the input (more negative), the closer the output will be to $-1.0$.
#
# Mathematically it can be represented as:
#
# \begin{equation}
# f(x) = \tanh(x) = \frac{e^x - e^{-x}}{e^x + e^{-x}}
# \end{equation}
#
# Advantages of using this activation function are:
#
# - The output of the tanh activation function is zero centered; hence we can easily map the output values as strongly negative, neutral, or strongly positive.
# - Usually used in hidden layers of a neural network as its values lie between -$1$ to; therefore, the mean for the hidden layer comes out to be $0$ or very close to it. It helps in centering the data and makes learning for the next layer much easier.
#
# **References**:
#
# - https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html
# - https://cs231n.github.io/neural-networks-1/
# - https://www.v7labs.com/blog/neural-networks-activation-functions

# %%
import numpy as np
from matplotlib import pyplot as plt 

def hyperbolic_tangent(x):
    return np.tanh(x)
    
x = np.arange(-5, 5, 0.1)

plt.figure(figsize=(10,10))
plt.title("Hyperbolic Tangent Function")
plt.xlabel("X") 
plt.ylabel("Y") 
plt.plot(x, hyperbolic_tangent(x),'r') 
plt.grid()
plt.show()

# %% [markdown]
# ## Rectified Linear Unit Function (ReLU)
#
# Although it gives an impression of a linear function, ReLU has a derivative function and allows for backpropagation while simultaneously making it computationally efficient.
#
# The main catch here is that the ReLU function does not activate all the neurons at the same time. The neurons will only be deactivated if the output of the linear transformation is less than 0.
#
# \begin{equation}
# f(x) =
# \begin{cases}
#     x & \text{if } x \ge 0 \\
#     0 & \text{if } x < 0 \\
# \end{cases}
# \end{equation}
#
# The advantages of using ReLU as an activation function are as follows:
#
# - Since only a certain number of neurons are activated, the ReLU function is far more computationally efficient when compared to the sigmoid and tanh functions.
# - ReLU accelerates the convergence of gradient descent towards the global minimum of the loss function due to its linear, non-saturating property.
#
# **References**:
#
# - https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html
# - https://cs231n.github.io/neural-networks-1/
# - https://www.v7labs.com/blog/neural-networks-activation-functions

# %%
import numpy as np
from matplotlib import pyplot as plt 

def relu(x):
    return np.maximum(x, 0)

x = np.arange(-5, 5, 0.1)

plt.figure(figsize=(10,10))
plt.title("ReLU Function")
plt.xlabel("X") 
plt.ylabel("Y") 
plt.plot(x, relu(x),'r') 
plt.grid()
plt.show()

# %% [markdown]
# ## Leaky Rectified Linear Unit Function (Leaky ReLU)
#
# Leaky ReLU is an improved version of ReLU function to solve the Dying ReLU problem as it has a small positive slope in the negative area. Mathematically it can be represented as:
#
# \begin{equation}
# f(x) =
# \begin{cases}
#     x & \text{if } x \ge 0 \\
#     0.01x & \text{if } x < 0 \\
# \end{cases}
# \end{equation}
#
# The advantages of Leaky ReLU are same as that of ReLU, in addition to the fact that it does enable backpropagation, even for negative input values. By making this minor modification for negative input values, the gradient of the left side of the graph comes out to be a non-zero value. Therefore, we would no longer encounter dead neurons in that region.
#
# **References**:
#
# - https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html
# - https://cs231n.github.io/neural-networks-1/
# - https://www.v7labs.com/blog/neural-networks-activation-functions

# %%
import numpy as np
from matplotlib import pyplot as plt 

def leaky_relu(x):
    return np.maximum(x, 0.1*x)

x = np.arange(-5, 5, 0.1)

plt.figure(figsize=(10,10))
plt.title("Leaky ReLU Function")
plt.xlabel("X") 
plt.ylabel("Y") 
plt.plot(x, leaky_relu(x),'r') 
plt.grid()
plt.show()

# %% [markdown]
# ## Softmax Function
#
# Softmax function calculates the probabilities distribution of the event over ‘n’ different events. In general way of saying, this function will calculate the probabilities of each target class over all possible target classes. Later the calculated probabilities will be helpful for determining the target class for the given inputs.
#
# The softmax function is defined as:
#
# \begin{equation}
# f(x) = \frac{e^x}{\sum_{i=1}^n e^x_i}
# \end{equation}
#
# **References**:
#
# - https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html
# - https://cs231n.github.io/neural-networks-1/
# - https://www.v7labs.com/blog/neural-networks-activation-functions

# %%
import numpy as np
from matplotlib import pyplot as plt 

def softmax(x):
    return np.exp(x)/np.sum(np.exp(x))

x = np.arange(-5, 5, 0.1)

plt.figure(figsize=(10,10))
plt.title("Softmax Function")
plt.xlabel("X") 
plt.ylabel("Y") 
plt.plot(x, softmax(x),'r') 
plt.grid()
plt.show()

# %% [markdown]
# ## Softplus Function
#
# The softplus function is a smooth approximation to the ReLU activation function, and is sometimes used in the neural networks in place of ReLU. It is defined as:
#
# \begin{equation}
# f(x) = \ln(1 + e^{x})
# \end{equation}
#
#
#
# **References**:
#
# - https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html
# - https://cs231n.github.io/neural-networks-1/
# - https://www.v7labs.com/blog/neural-networks-activation-functions

# %%
import numpy as np
from matplotlib import pyplot as plt 

def softplus(x):
    return np.log(1+np.exp(x))

x = np.arange(-5, 5, 0.1)

plt.figure(figsize=(10,10))
plt.title("Softplus Function")
plt.xlabel("X") 
plt.ylabel("Y") 
plt.plot(x, softplus(x),'r') 
plt.grid()
plt.show()

# %% [markdown]
# ## Softminus Function
#
# The softminus function is a smooth approximation to the negative ReLU activation function, and is sometimes used in the neural networks in place of negative ReLU. It is defined as:
#
# \begin{equation}
# f(x) = x - \ln(1 + e^{-x})
# \end{equation}
#
# **References**:
#
# - https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html
# - https://cs231n.github.io/neural-networks-1/
# - https://www.v7labs.com/blog/neural-networks-activation-functions

# %%
import numpy as np
from matplotlib import pyplot as plt 

def softminus(x):
    return x - np.log(1+np.exp(-x))
    
x = np.arange(-5, 5, 0.1)

plt.figure(figsize=(10,10))
plt.title("Softminus Function")
plt.xlabel("X") 
plt.ylabel("Y") 
plt.plot(x, softminus(x),'r') 
plt.grid()
plt.show()
# Out:
# C:\Users\jpmh1\AppData\Local\Temp/ipykernel_20560/424505449.py:5: RuntimeWarning: invalid value encountered in log
#   return np.log(1-np.exp(-x))

# %% [markdown]
# # Gradient Descent
#
# Gradient descent is an optimization algorithm used to minimize some function by iteratively moving in the direction of steepest descent as defined by the negative of the gradient. In machine learning, we use gradient descent to update the parameters of our model. Parameters refer to coefficients in linear regression and weights in neural networks. A gradient measures how much the output of a function changes if you change the inputs a little bit.
#
# ![ensemble](images/gd.jpeg)
#
# Gradient descent algorithm does not work for all functions. There are two specific requirements. A function has to be:
#
# - differentiable
# - convex
#
# First, what does it mean it has to be differentiable? If a function is differentiable it has a derivative for each point in its domain — not all functions meet these criteria. Second requirement — function has to be convex. For a univariate function, this means that the line segment connecting two function’s points lays on or above its curve (it does not cross it). If it does it means that it has a local minimum which is not a global one.
#
# What is a gradient. Intuitively it is a slope of a curve at a given point in a specified direction. In the case of a univariate function, it is simply the first derivative at a selected point. In the case of a multivariate function, it is a vector of derivatives in each main direction (along variable axes). Because we are interested only in a slope along one axis and we don’t care about others these derivatives are called partial derivatives.
#
# A gradient for an n-dimensional function f(x) at a given point p is defined as follows:
#
# \begin{equation}
# \nabla f(x) = \frac{\partial f}{\partial x_i}
# \end{equation}
#
# where $x_i$ is the $i^{th}$ coordinate of the point $p$.
#
# ## Algorithm
#
# In summary, gradient descent method’s steps are:
#
# 1. Choose a starting point $x_0$
# 2. Calculate the gradient at $x_0$
# 3. Choose a step size $\alpha$
# 4. Move in the direction of the gradient $\alpha \times \nabla f(x_0)$
# 5. Repeat steps 2-4 until convergence
#
# This is defined with the following formula:
#
# \begin{equation}
# x_{k+1} = x_k - \alpha \times \nabla f(x_k)
# \end{equation}
#
# Some important parameters of gradient descent:
#
# - step size: $\alpha$
# - starting point: $x_0$
# - maximum number of iterations: $N$
# - gradient function: $\nabla f(x)$
#
# ## Learning Rate
#
# The size of these steps is called the learning rate. With a high learning rate we can cover more ground each step, but we risk overshooting the lowest point since the slope of the hill is constantly changing. With a very low learning rate, we can confidently move in the direction of the negative gradient since we are recalculating it so frequently. A low learning rate is more precise, but calculating the gradient is time-consuming, so it will take us a very long time to get to the bottom.
#
# ## Cost Function
#
# A loss functions tells us “how good” our model is at making predictions for a given set of parameters. The cost function has its own curve and its own gradients. The slope of this curve tells us how to update our parameters to make the model more accurate.
#
# **References**:
#
# - https://towardsdatascience.com/gradient-descent-algorithm-a-deep-dive-cf04e8115f21
# - https://builtin.com/data-science/gradient-descent
# - https://ml-cheatsheet.readthedocs.io/en/latest/gradient_descent.html
# - https://ruder.io/optimizing-gradient-descent/
# - Ruder, S. (2016). An overview of gradient descent optimization algorithms. ArXiv, abs/1609.04747.

# %%
import numpy as np
from matplotlib import pyplot as plt 

def gradient_descent(start, gradient, learn_rate, max_iter, tol=0.01):
  steps = [start] # history tracking
  x = start

  for _ in range(max_iter):
    diff = learn_rate*gradient(x)
    if np.abs(diff)<tol:
      break    
    x = x - diff
    steps.append(x) # history tracing

  return steps, x


def func1(x):
  return x**2-4*x+1

def gradient_func1(x):
  return 2*x - 4

history, result = gradient_descent(9, gradient_func1, 0.1, 100)
x = np.arange(-2, 10, 0.1)
history = np.array(history) 

plt.figure(figsize=(10,10))
plt.title("Gradient Descent")
plt.xlabel("X") 
plt.ylabel("Y") 
plt.plot(x,func1(x),'r') 
plt.plot(history, func1(history), 'bo')
plt.plot(result, func1(result), 'go')
plt.grid()
plt.show()

# %% [markdown]
# # Optimization Methods
#
# ## Batch Gradient Descent
#
# **References**:
#
# - https://towardsdatascience.com/support-vector-machine-introduction-to-machine-learning-algorithms-934a444fca47
# - https://scikit-learn.org/stable/modules/classes.html#module-sklearn.svm
# - https://www.analyticsvidhya.com/blog/2017/09/understaing-support-vector-machine-example-code/
# - https://www.analyticsvidhya.com/blog/2014/10/support-vector-machine-simplified/?utm_source=blog&utm_medium=understandingsupportvectormachinearticle
# - https://www.analyticsvidhya.com/blog/2020/10/the-mathematics-behind-svm/#:~:text=A%20Support%20Vector%20Machine%20or,to%20as%20Support%20Vector%20Classification.
# - https://ankitnitjsr13.medium.com/math-behind-support-vector-machine-svm-5e7376d0ee4d

# %% [markdown]
# # Softmax
#
# **References**:
#
# - https://towardsdatascience.com/support-vector-machine-introduction-to-machine-learning-algorithms-934a444fca47
# - https://scikit-learn.org/stable/modules/classes.html#module-sklearn.svm
# - https://www.analyticsvidhya.com/blog/2017/09/understaing-support-vector-machine-example-code/
# - https://www.analyticsvidhya.com/blog/2014/10/support-vector-machine-simplified/?utm_source=blog&utm_medium=understandingsupportvectormachinearticle
# - https://www.analyticsvidhya.com/blog/2020/10/the-mathematics-behind-svm/#:~:text=A%20Support%20Vector%20Machine%20or,to%20as%20Support%20Vector%20Classification.
# - https://ankitnitjsr13.medium.com/math-behind-support-vector-machine-svm-5e7376d0ee4d

# %% [markdown]
# # One Hot Encoding
#
# **References**:
#
# - https://towardsdatascience.com/support-vector-machine-introduction-to-machine-learning-algorithms-934a444fca47
# - https://scikit-learn.org/stable/modules/classes.html#module-sklearn.svm
# - https://www.analyticsvidhya.com/blog/2017/09/understaing-support-vector-machine-example-code/
# - https://www.analyticsvidhya.com/blog/2014/10/support-vector-machine-simplified/?utm_source=blog&utm_medium=understandingsupportvectormachinearticle
# - https://www.analyticsvidhya.com/blog/2020/10/the-mathematics-behind-svm/#:~:text=A%20Support%20Vector%20Machine%20or,to%20as%20Support%20Vector%20Classification.
# - https://ankitnitjsr13.medium.com/math-behind-support-vector-machine-svm-5e7376d0ee4d

# %% [markdown]
# ## Epochs
#
# **References**:
#
# - https://towardsdatascience.com/support-vector-machine-introduction-to-machine-learning-algorithms-934a444fca47
# - https://scikit-learn.org/stable/modules/classes.html#module-sklearn.svm
# - https://www.analyticsvidhya.com/blog/2017/09/understaing-support-vector-machine-example-code/
# - https://www.analyticsvidhya.com/blog/2014/10/support-vector-machine-simplified/?utm_source=blog&utm_medium=understandingsupportvectormachinearticle
# - https://www.analyticsvidhya.com/blog/2020/10/the-mathematics-behind-svm/#:~:text=A%20Support%20Vector%20Machine%20or,to%20as%20Support%20Vector%20Classification.
# - https://ankitnitjsr13.medium.com/math-behind-support-vector-machine-svm-5e7376d0ee4d

# %% [markdown]
# ## Batch Size
#
# **References**:
#
# - https://towardsdatascience.com/support-vector-machine-introduction-to-machine-learning-algorithms-934a444fca47
# - https://scikit-learn.org/stable/modules/classes.html#module-sklearn.svm
# - https://www.analyticsvidhya.com/blog/2017/09/understaing-support-vector-machine-example-code/
# - https://www.analyticsvidhya.com/blog/2014/10/support-vector-machine-simplified/?utm_source=blog&utm_medium=understandingsupportvectormachinearticle
# - https://www.analyticsvidhya.com/blog/2020/10/the-mathematics-behind-svm/#:~:text=A%20Support%20Vector%20Machine%20or,to%20as%20Support%20Vector%20Classification.
# - https://ankitnitjsr13.medium.com/math-behind-support-vector-machine-svm-5e7376d0ee4d

# %% [markdown]
# ## Iterations
#
# **References**:
#
# - https://towardsdatascience.com/support-vector-machine-introduction-to-machine-learning-algorithms-934a444fca47
# - https://scikit-learn.org/stable/modules/classes.html#module-sklearn.svm
# - https://www.analyticsvidhya.com/blog/2017/09/understaing-support-vector-machine-example-code/
# - https://www.analyticsvidhya.com/blog/2014/10/support-vector-machine-simplified/?utm_source=blog&utm_medium=understandingsupportvectormachinearticle
# - https://www.analyticsvidhya.com/blog/2020/10/the-mathematics-behind-svm/#:~:text=A%20Support%20Vector%20Machine%20or,to%20as%20Support%20Vector%20Classification.
# - https://ankitnitjsr13.medium.com/math-behind-support-vector-machine-svm-5e7376d0ee4d

# %% [markdown]
# # Dropout
#
# **References**:
#
# - https://towardsdatascience.com/support-vector-machine-introduction-to-machine-learning-algorithms-934a444fca47
# - https://scikit-learn.org/stable/modules/classes.html#module-sklearn.svm
# - https://www.analyticsvidhya.com/blog/2017/09/understaing-support-vector-machine-example-code/
# - https://www.analyticsvidhya.com/blog/2014/10/support-vector-machine-simplified/?utm_source=blog&utm_medium=understandingsupportvectormachinearticle
# - https://www.analyticsvidhya.com/blog/2020/10/the-mathematics-behind-svm/#:~:text=A%20Support%20Vector%20Machine%20or,to%20as%20Support%20Vector%20Classification.
# - https://ankitnitjsr13.medium.com/math-behind-support-vector-machine-svm-5e7376d0ee4d

# %% [markdown]
# ## Stride
#
# **References**:
#
# - https://towardsdatascience.com/support-vector-machine-introduction-to-machine-learning-algorithms-934a444fca47
# - https://scikit-learn.org/stable/modules/classes.html#module-sklearn.svm
# - https://www.analyticsvidhya.com/blog/2017/09/understaing-support-vector-machine-example-code/
# - https://www.analyticsvidhya.com/blog/2014/10/support-vector-machine-simplified/?utm_source=blog&utm_medium=understandingsupportvectormachinearticle
# - https://www.analyticsvidhya.com/blog/2020/10/the-mathematics-behind-svm/#:~:text=A%20Support%20Vector%20Machine%20or,to%20as%20Support%20Vector%20Classification.
# - https://ankitnitjsr13.medium.com/math-behind-support-vector-machine-svm-5e7376d0ee4d

# %% [markdown]
# ## Padding
#
# **References**:
#
# - https://towardsdatascience.com/support-vector-machine-introduction-to-machine-learning-algorithms-934a444fca47
# - https://scikit-learn.org/stable/modules/classes.html#module-sklearn.svm
# - https://www.analyticsvidhya.com/blog/2017/09/understaing-support-vector-machine-example-code/
# - https://www.analyticsvidhya.com/blog/2014/10/support-vector-machine-simplified/?utm_source=blog&utm_medium=understandingsupportvectormachinearticle
# - https://www.analyticsvidhya.com/blog/2020/10/the-mathematics-behind-svm/#:~:text=A%20Support%20Vector%20Machine%20or,to%20as%20Support%20Vector%20Classification.
# - https://ankitnitjsr13.medium.com/math-behind-support-vector-machine-svm-5e7376d0ee4d

# %% [markdown]
# # Pooling
#
# **References**:
#
# - https://towardsdatascience.com/support-vector-machine-introduction-to-machine-learning-algorithms-934a444fca47
# - https://scikit-learn.org/stable/modules/classes.html#module-sklearn.svm
# - https://www.analyticsvidhya.com/blog/2017/09/understaing-support-vector-machine-example-code/
# - https://www.analyticsvidhya.com/blog/2014/10/support-vector-machine-simplified/?utm_source=blog&utm_medium=understandingsupportvectormachinearticle
# - https://www.analyticsvidhya.com/blog/2020/10/the-mathematics-behind-svm/#:~:text=A%20Support%20Vector%20Machine%20or,to%20as%20Support%20Vector%20Classification.
# - https://ankitnitjsr13.medium.com/math-behind-support-vector-machine-svm-5e7376d0ee4d

# %% [markdown]
# # PlotNeuralNet
#
# **References**:
#
# - https://towardsdatascience.com/support-vector-machine-introduction-to-machine-learning-algorithms-934a444fca47
# - https://scikit-learn.org/stable/modules/classes.html#module-sklearn.svm
# - https://www.analyticsvidhya.com/blog/2017/09/understaing-support-vector-machine-example-code/
# - https://www.analyticsvidhya.com/blog/2014/10/support-vector-machine-simplified/?utm_source=blog&utm_medium=understandingsupportvectormachinearticle
# - https://www.analyticsvidhya.com/blog/2020/10/the-mathematics-behind-svm/#:~:text=A%20Support%20Vector%20Machine%20or,to%20as%20Support%20Vector%20Classification.
# - https://ankitnitjsr13.medium.com/math-behind-support-vector-machine-svm-5e7376d0ee4d
